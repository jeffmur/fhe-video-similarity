# %% [markdown]
# # Supervised Learning 🤖
#
# This notebook serves to generate F1 Score, Precision, Recall, and Accuracy to compare to the results of the supervised learning models from SSO.
#
# **Field of View (FOV) Dataset**
#
# The field of view degrees are calculated counter-clockwise. Where 0 degrees is in front of the subject, 90 degrees is left of the subject, 180 degrees is behind the subject, and 270 degrees is right of the subject.
#
# As an additional note, some phones record in portrait or landscape mode. The dataset is comprised of 3 simultaneous, stationary mobile devices recording from various angles.
#
# Data Collection:
#
# *1_office*: Recording from various angles of myself for 20 minutes at my desk listening to music.
#
# Google Pixel 3XL - Landscape - 90 degrees
#
# iPhone 13 - Landscape - 180 degrees
#
# Samsung Galaxy S9 - Portrait - 270 degrees
#
# *2_vaccum*: Recording from various angles of myself for 20 minutes vacuuming my living room.
#
# Google Pixel 3XL - Landscape - 270 degrees (failed to record)
#
# iPhone 13 - Landscape - 90 degrees
#
# Samsung Galaxy S9 - Portrait - 180 degrees

# %% [markdown]
# ## Approach 1: Strict Classification
#
# Classify only the exact same segments (space, time, and angle) as 1, otherwise 0.

# %%
from utils.ann import train_test_ann, dir_to_df, grid_search_ann, confusionMatrix

# %% [markdown]
# ### Experiment 1: Low Movement

# %%
y_test, y_pred, y_pred_proba, results =  train_test_ann(dir_to_df('2_fov/1_office/strict_train_similarity_scores')).values()
confusionMatrix(y_test, y_pred)
# Out:
# Accuracy: 98.48%
# Error: 1.52%
# Precision: 96.98%
# Recall: 98.48%
# F1 Score: 97.73%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_test, y_pred, y_pred_proba, results = grid_search_ann(dir_to_df('2_fov/1_office/strict_train_similarity_scores')).values()
confusionMatrix(y_test, y_pred)
# Out:
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %% [markdown]
# ### Experiment 2: High Movement

# %%
y_test, y_pred, y_pred_proba, results =  train_test_ann(dir_to_df('2_fov/2_vacuum/strict_train_similarity_scores')).values()
confusionMatrix(y_test, y_pred)
# Out:
# Accuracy: 97.58%
# Error: 2.42%
# Precision: 95.21%
# Recall: 97.58%
# F1 Score: 96.38%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_test, y_pred, y_pred_proba, results = grid_search_ann(dir_to_df('2_fov/2_vacuum/strict_train_similarity_scores')).values()
confusionMatrix(y_test, y_pred)
# Out:
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %% [markdown]
# ### Experiment 4: Train on all data

# %%
import pandas as pd

df_1 = dir_to_df('2_fov/1_office/strict_train_similarity_scores')
df_2 = dir_to_df('2_fov/2_vacuum/strict_train_similarity_scores')
df_3 = dir_to_df('2_fov/3_compare_1_2/strict_train_similarity_scores')
df = pd.concat([df_1, df_2])

y_test, y_pred, y_pred_proba, results = train_test_ann(df, df_3).values()
confusionMatrix(y_test, y_pred)
# Out:
# Accuracy: 100.00%
# Error: 0.00%
# Precision: 100.00%
# Recall: 100.00%
# F1 Score: 100.00%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
y_test, y_pred, y_pred_proba, results = grid_search_ann(df, df_3).values()
confusionMatrix(y_test, y_pred)
# Out:
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %% [markdown]
# ### Experiment 4: Train on Low Movement, Test on High Movement

# %%
y_test, y_pred, y_pred_proba, results = train_test_ann(df_1, df_2).values()
confusionMatrix(y_test, y_pred)
# Out:
# Accuracy: 97.37%
# Error: 2.63%
# Precision: 94.81%
# Recall: 97.37%
# F1 Score: 96.07%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Experiment 5: Train on High Movement, Test on Low Movement

# %%
y_test, y_pred, y_pred_proba, results = train_test_ann(df_2, df_1).values()
confusionMatrix(y_test, y_pred)
# Out:
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Accuracy: 98.24%
# Error: 1.76%
# Precision: 96.50%
# Recall: 98.24%
# F1 Score: 97.36%

# %% [markdown]
# ## Approach 2: Flexible Classification
#
# Following the work from SSO and Pop-Share, assign 1 to the first pair of segments of the comparison of similar videos.

# %%
from utils.ann import train_test_ann, dir_to_df, grid_search_ann, confusionMatrix, train_test_md_table

results_mat = []

# %% [markdown]
# ### Experiment 1: Low Movement

# %%
y_test, y_pred, y_pred_proba, results =  train_test_ann(dir_to_df('2_fov/1_office/flex_train_similarity_scores')).values()
confusionMatrix(y_test, y_pred)
results_mat.append({'office_default': results})
# Out:
# Accuracy: 97.42%
# Error: 2.58%
# Precision: 94.90%
# Recall: 97.42%
# F1 Score: 96.14%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_test, y_pred, y_pred_proba, results = grid_search_ann(dir_to_df('2_fov/1_office/flex_train_similarity_scores')).values()
confusionMatrix(y_test, y_pred)
results_mat.append({'office_gridSearch': results})
# Out:
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %% [markdown]
# ### Experiment 2: High Movement

# %%
y_test, y_pred, y_pred_proba, results =  train_test_ann(dir_to_df('2_fov/2_vacuum/flex_train_similarity_scores')).values()
confusionMatrix(y_test, y_pred)
results_mat.append({'vacuum_default': results})
# Out:
# Accuracy: 97.58%
# Error: 2.42%
# Precision: 95.21%
# Recall: 97.58%
# F1 Score: 96.38%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_test, y_pred, y_pred_proba, results = grid_search_ann(dir_to_df('2_fov/2_vacuum/flex_train_similarity_scores')).values()
confusionMatrix(y_test, y_pred)
results_mat.append({'vacuum_gridSearch': results})
# Out:
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %% [markdown]
# ### Experiment 4: Train on all data

# %%
import pandas as pd

df_1 = dir_to_df('2_fov/1_office/flex_train_similarity_scores')
df_2 = dir_to_df('2_fov/2_vacuum/flex_train_similarity_scores')
df_3 = dir_to_df('2_fov/3_compare_1_2/flex_train_similarity_scores')
df = pd.concat([df_1, df_2])

y_test, y_pred, y_pred_proba, results = train_test_ann(df, df_3).values()
confusionMatrix(y_test, y_pred)
results_mat.append({'office_vs_vacuum_default': results})
# Out:
# Accuracy: 99.82%
# Error: 0.18%
# Precision: 100.00%
# Recall: 99.82%
# F1 Score: 99.91%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
y_test, y_pred, y_pred_proba, results = grid_search_ann(df, df_3).values()
confusionMatrix(y_test, y_pred)
results_mat.append({'office_vs_vacuum_gridSearch': results})
# Out:
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:545: ConvergenceWarning: lbfgs failed to converge (status=2):
# ABNORMAL_TERMINATION_IN_LNSRCH.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# ...

# %% [markdown]
# ### Experiment 4: Train on Low Movement, Test on High Movement

# %%
y_test, y_pred, y_pred_proba, results = train_test_ann(df_1, df_2).values()
confusionMatrix(y_test, y_pred)
results_mat.append({'train_office_test_vacuum_default': results})
# Out:
# Accuracy: 97.23%
# Error: 2.77%
# Precision: 94.54%
# Recall: 97.23%
# F1 Score: 95.86%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# ### Experiment 5: Train on High Movement, Test on Low Movement

# %%
y_test, y_pred, y_pred_proba, results = train_test_ann(df_2, df_1).values()
confusionMatrix(y_test, y_pred)
results_mat.append({'train_vacuum_test_office_default': results})
# Out:
# Accuracy: 98.05%
# Error: 1.95%
# Precision: 96.14%
# Recall: 98.05%
# F1 Score: 97.09%
# /home/jeffmur/dev/fhe-video-similarity/results/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
train_test_md_table(results_mat)
# Out:
# Label | Accuracy | Precision | Recall | F1 Score
# ---|---|---|---|---
# office_default | 0.97 | 0.95 | 0.97 | 0.96
# office_gridSearch | 1.00 | 1.00 | 1.00 | 1.00
# vacuum_default | 0.98 | 0.95 | 0.98 | 0.96
# vacuum_gridSearch | 1.00 | 1.00 | 1.00 | 1.00
# office_vs_vacuum_default | 1.00 | 1.00 | 1.00 | 1.00
# office_vs_vacuum_gridSearch | 1.00 | 1.00 | 1.00 | 1.00
# train_office_test_vacuum_default | 0.97 | 0.95 | 0.97 | 0.96
# train_vacuum_test_office_default | 0.98 | 0.96 | 0.98 | 0.97
